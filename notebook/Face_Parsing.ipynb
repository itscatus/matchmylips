# %% [markdown]
# Mounting Drive Folders

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Install requirement.

# %%
# !pip install git+https://github.com/FacePerceiver/facer.git@main
# !git clone https://github.com/FacePerceiver/facer.git
# Out:
# Collecting git+https://github.com/FacePerceiver/facer.git@main
#   Cloning https://github.com/FacePerceiver/facer.git (to revision main) to /tmp/pip-req-build-1fo7py7d
#   Running command git clone --filter=blob:none --quiet https://github.com/FacePerceiver/facer.git /tmp/pip-req-build-1fo7py7d
#   Encountered 16 file(s) that should have been pointers, but weren't:
#         samples/data/fire.webp
#         samples/data/girl.jpg
#         samples/data/sideface.jpg
#         samples/data/twogirls.jpg
#         samples/data/weirdface.jpg
#         samples/data/weirdface2.jpg
#         samples/data/weirdface3.jpg
#         samples/download.ipynb
#         samples/example_output/alignment.png
#         samples/example_output/detect.png
#         samples/example_output/parsing.png
#         samples/face_alignment.ipynb
#         samples/face_attribute.ipynb
#         samples/face_detect.ipynb
#         samples/face_parsing.ipynb
#         samples/transform.ipynb
#   Resolved https://github.com/FacePerceiver/facer.git to commit f0dd2d67def16445454b90a191cc763431795979
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (0.20.1+cu121)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (1.0.12)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (11.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (1.26.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (7.7.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (0.25.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (3.10.0)
# Collecting validators (from pyfacer==0.0.4)
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (2.32.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from pyfacer==0.0.4) (4.10.0.84)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->pyfacer==0.0.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9.1->pyfacer==0.0.4) (1.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->pyfacer==0.0.4) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyfacer==0.0.4) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyfacer==0.0.4) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyfacer==0.0.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyfacer==0.0.4) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyfacer==0.0.4) (2024.12.14)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pyfacer==0.0.4) (1.13.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pyfacer==0.0.4) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pyfacer==0.0.4) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pyfacer==0.0.4) (0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm->pyfacer==0.0.4) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm->pyfacer==0.0.4) (0.27.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->pyfacer==0.0.4) (0.5.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pyfacer==0.0.4) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->pyfacer==0.0.4) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pyfacer==0.0.4) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (6.5.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm->pyfacer==0.0.4) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.1->pyfacer==0.0.4) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (7.16.5)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->pyfacer==0.0.4) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.10/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pyfacer==0.0.4) (1.2.2)
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyfacer
#   Building wheel for pyfacer (setup.py) ... done
#   Created wheel for pyfacer: filename=pyfacer-0.0.4-py3-none-any.whl size=38717 sha256=7062fc7726bf170c0412108215f0f8045da6eb686625d6f02f291fba6c2f4dbc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j4r0sn11/wheels/9a/68/b6/aac9d5315644c30942fcb33cd6b1779cda9291c78b9501e21e
# Successfully built pyfacer
# Installing collected packages: validators, jedi, pyfacer
# Successfully installed jedi-0.19.2 pyfacer-0.0.4 validators-0.34.0
# Cloning into 'facer'...
# remote: Enumerating objects: 407, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 407 (delta 13), reused 8 (delta 5), pack-reused 376 (from 1)
# Receiving objects: 100% (407/407), 3.01 MiB | 33.82 MiB/s, done.
# Resolving deltas: 100% (190/190), done.
# Encountered 16 file(s) that should have been pointers, but weren't:
# 	samples/data/fire.webp
# 	samples/data/girl.jpg
# 	samples/data/sideface.jpg
# 	samples/data/twogirls.jpg
# 	samples/data/weirdface.jpg
# 	samples/data/weirdface2.jpg
# 	samples/data/weirdface3.jpg
# 	samples/download.ipynb
# 	samples/example_output/alignment.png
# 	samples/example_output/detect.png
# 	samples/example_output/parsing.png
# 	samples/face_alignment.ipynb
# 	samples/face_attribute.ipynb
# 	samples/face_detect.ipynb
# 	samples/face_parsing.ipynb
# 	samples/transform.ipynb

# %% [markdown]
# Face Parsing for single image

# %%
import torch
import cv2
import numpy as np
import facer

def save_skin_mask(img_path, output_path="temp.jpg"):
    # Using CUDA GPU if available
    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    # Read and pre-process the image for Facer
    sample = cv2.imread(img_path)
    if sample is None:
        print(f"Error: Unable to read image at {img_path}")
        return
    img = cv2.cvtColor(sample, cv2.COLOR_BGR2RGB)

    # Convert img (numpy array) to PyTorch tensor
    image = torch.from_numpy(img).to(device=device)

    # Change the order of the dimensions from HWC to CHW
    image = image.permute(2, 0, 1).unsqueeze(0)

    # Load Facer models
    face_detector = facer.face_detector('retinaface/mobilenet', device=device)
    face_parser = facer.face_parser('farl/lapa/448', device=device)

    with torch.inference_mode():
        faces = face_detector(image)
        if faces['rects'].nelement() == 0:
            print(f"No faces detected in {img_path}, skipping...")
            return

        if 'image_ids' in faces:
            faces['image_ids'] = faces['image_ids'].long()
        faces = face_parser(image, faces)

    # Parse the face skin
    seg_logits = faces['seg']['logits']
    seg_probs = seg_logits.softmax(dim=1).cpu()  # Ensure CPU for numpy compatibility
    tensor = seg_probs.permute(0, 2, 3, 1).squeeze().numpy()
    face_skin = tensor[:, :, 1]

    # Create binary mask
    binary_mask = (face_skin >= 0.5).astype(np.uint8)

    # Debug mask dimensions
    if binary_mask.ndim != 2:
        print(f"Mask dimension issue in {img_path}: {binary_mask.shape}")
        return

    # Resize binary mask to match the original image
    binary_mask = cv2.resize(binary_mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)

    # Create masked image
    masked_image = np.zeros_like(img)
    try:
        masked_image[binary_mask == 1] = img[binary_mask == 1]
        masked_image = cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB)
        cv2.imwrite(output_path, masked_image)
        print(f"Masked image saved to {output_path}")
    except Exception as e:
        print(f"Error occurred while creating the masked image: {e}")

# Example Usage
save_skin_mask("./facer/samples/data/girl.jpg", "output_masked.jpg")
# Out:
# Masked image saved to output_masked.jpg

# %% [markdown]
# Face Parsing for dataset folder

# %%
import os
import cv2
import numpy as np
import torch
import facer

# Paths
base_path = '/content/drive/MyDrive/Deep_Armocromia/'
data_types = ['train', 'test']
output_folder = '/content/drive/MyDrive/extracted_skin'

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load facer models
face_detector = facer.face_detector('retinaface/mobilenet', device=device)
face_parser = facer.face_parser('farl/lapa/448', device=device)

# Process images
for data_type in data_types:
    data_path = os.path.join(base_path, data_type)
    output_data_path = os.path.join(output_folder, data_type)
    os.makedirs(output_data_path, exist_ok=True)

    # Iterate through seasons (autumn, spring, etc.)
    for season_name in os.listdir(data_path):
        season_path = os.path.join(data_path, season_name)
        output_season_path = os.path.join(output_data_path, season_name)
        os.makedirs(output_season_path, exist_ok=True)

        # Iterate through sub-seasons (deep autumn, etc.)
        for sub_season_name in os.listdir(season_path):
            sub_season_path = os.path.join(season_path, sub_season_name)
            output_sub_season_path = os.path.join(output_season_path, sub_season_name)
            os.makedirs(output_sub_season_path, exist_ok=True)

            if os.path.isdir(sub_season_path):
                for filename in os.listdir(sub_season_path):
                    if filename.endswith(('.jpg', '.png')):
                        sample_path = os.path.join(sub_season_path, filename)
                        sample = cv2.imread(sample_path)

                        # Check if image is loaded properly
                        if sample is None:
                            print(f"Failed to load image: {sample_path}")
                            continue

                        img = cv2.cvtColor(sample, cv2.COLOR_BGR2RGB)

                        # Read and preprocess the image for facer
                        image = facer.hwc2bchw(facer.read_hwc(sample_path)).to(device=device)
                        with torch.inference_mode():
                            faces = face_detector(image)
                            if faces['rects'].nelement() == 0:
                                print(f"No faces detected in {filename}, skipping...")
                                continue
                            if 'image_ids' in faces:
                                faces['image_ids'] = faces['image_ids'].long()
                            faces = face_parser(image, faces)

                        # Parse the face skin
                        seg_logits = faces['seg']['logits']
                        seg_probs = seg_logits.softmax(dim=1).cpu()
                        tensor = seg_probs.permute(0, 2, 3, 1).squeeze().numpy()
                        face_skin = tensor[:, :, 1]

                        # Create binary mask
                        binary_mask = (face_skin >= 0.5).astype(int)

                        # Debug mask dimensions
                        if binary_mask.ndim != 2:
                            print(f"Mask dimension issue in {filename}: {binary_mask.shape}")
                            continue

                        # Resize binary mask to match image
                        # binary_mask = cv2.resize(binary_mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)

                        # Create masked image
                        masked_image = np.zeros_like(img)
                        masked_image[binary_mask == 1] = img[binary_mask == 1]

                        # Convert to BGR for saving
                        masked_image_rgb = cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB)

                        # Save masked image
                        output_image_path = os.path.join(output_sub_season_path, filename)
                        success = cv2.imwrite(output_image_path, masked_image_rgb)
                        if success:
                            print(f"Saved masked image to: {output_image_path}")
                        else:
                            print(f"Failed to save masked image: {output_image_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/laura graham 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani44.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/Katy Perry__1.png
# Mask dimension issue in paola turani52.png: (2, 694, 11)
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani63.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani49.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani53.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/alice-basso1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/raoul bova 2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani46.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani43.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/elizabeth taylor 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani41.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/MARION COTILLARD 2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/eva green 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/annie mazzola 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani51.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/Megan Fox__2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani50.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/giulia valentino 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/matt bomer 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/zooey deschanel 2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/megan gale 2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/marion cotillard 1_1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/fotini peluso 2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/LIV TYLER 3.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani42.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/MEGAN FOX 1_1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/fotini peluso-inverno bright.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/25458.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/liv tyler1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/giulia valentina-inverno bright.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/8653.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani47.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani27.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani5.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani38.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/nicole mazzocato 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/megan fox 2_1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/jennifer connelly 1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/olivia munn-inverno bright.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/22577.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani25.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/megan gale-inverno bright.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/22546.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/17473.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani54.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/22989.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani48.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani39.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/20904.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/18516.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/24545.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/LIV TYLER 2_1.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/liv tyler2.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/jenniefer connelly-inverno bright.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/12681.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola turani36.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/15628.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/27491.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/26603.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/25868.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/7890.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/26062.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/12284.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/12222.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/21596.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/17172.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/15464.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/11905.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/train/winter/clear winter/paola tur
png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/test/winter/deep winter/26530.png
# Saved masked image to: /content/drive/MyDrive/extracted_skin/test/winter/deep winter/1514.png

# %% [markdown]
# cropped to only face mask size

# %%
import os
import cv2
import numpy as np
import torch
import facer

# Paths
base_path = '/content/drive/MyDrive/extracted_face-skin/'
data_types = ['train', 'test']
output_folder = '/content/drive/MyDrive/skin_only_images'

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load facer models
face_detector = facer.face_detector('retinaface/mobilenet', device=device)
face_parser = facer.face_parser('farl/lapa/448', device=device)

# Process images
for data_type in data_types:
    data_path = os.path.join(base_path, data_type)
    output_data_path = os.path.join(output_folder, data_type)
    os.makedirs(output_data_path, exist_ok=True)

    for folder_name in os.listdir(data_path):
        folder_path = os.path.join(data_path, folder_name)
        output_folder_path = os.path.join(output_data_path, folder_name)
        os.makedirs(output_folder_path, exist_ok=True)

        if os.path.isdir(folder_path):
            for filename in os.listdir(folder_path):
                if filename.endswith(('.jpg', '.png')):
                    sample_path = os.path.join(folder_path, filename)
                    sample = cv2.imread(sample_path)

                    # Check if image is loaded properly
                    if sample is None:
                        print(f"Failed to load image: {sample_path}")
                        continue

                    img = cv2.cvtColor(sample, cv2.COLOR_BGR2RGB)

                    # Read and preprocess the image for facer
                    image = facer.hwc2bchw(facer.read_hwc(sample_path)).to(device=device)
                    with torch.inference_mode():
                        faces = face_detector(image)
                        if faces['rects'].nelement() == 0:
                            print(f"No faces detected in {filename}, skipping...")
                            continue
                        if 'image_ids' in faces:
                            faces['image_ids'] = faces['image_ids'].long()
                        faces = face_parser(image, faces)

                    # Parse the face skin
                    seg_logits = faces['seg']['logits']
                    seg_probs = seg_logits.softmax(dim=1).cpu()
                    tensor = seg_probs.permute(0, 2, 3, 1).squeeze().numpy()
                    face_skin = tensor[:, :, 1]

                    # Create binary mask
                    binary_mask = (face_skin >= 0.5).astype(int)

                    # Debug mask dimensions
                    if binary_mask.ndim != 2:
                        print(f"Mask dimension issue in {filename}: {binary_mask.shape}")
                        continue

                    # Resize binary mask to match image
                    binary_mask = cv2.resize(binary_mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)

                    # Extract bounding box of the face skin
                    y_indices, x_indices = np.where(binary_mask == 1)
                    if len(y_indices) == 0 or len(x_indices) == 0:
                        print(f"No skin pixels found in {filename}, skipping...")
                        continue

                    # Calculate bounding box
                    x_min, x_max = x_indices.min(), x_indices.max()
                    y_min, y_max = y_indices.min(), y_indices.max()

                    # Crop the image to the bounding box
                    cropped_face_skin = img[y_min:y_max + 1, x_min:x_max + 1]

                    # Convert to BGR for saving
                    cropped_face_skin_bgr = cv2.cvtColor(cropped_face_skin, cv2.COLOR_BGR2RGB)

                    # Save the cropped image
                    output_image_path = os.path.join(output_folder_path, filename)
                    success = cv2.imwrite(output_image_path, cropped_face_skin_bgr)
                    if success:
                        print(f"Saved cropped face skin image to: {output_image_path}")
                    else:
                        print(f"Failed to save cropped face skin image: {output_image_path}")
# Out:
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/2125.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/6104.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/SHAKIRA 1.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/16517.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/Irene Colzi.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/5869.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/16071.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/anne hathaway21.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/7401.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/15022.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/natalie portman6.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/16498.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/anne hathaway18.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/16808.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/19325.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/Anne Hathaway6.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/Alessandra Airo.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/shakira11.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter/lily collins6.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/train/cool winter
png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/test/clear_spring/23166.png
# Saved cropped face skin image to: /content/drive/MyDrive/skin_only_images/test/clear_spring/3029.png

# %% [markdown]
# saving while renaming the file

# %%
import os
import cv2
import numpy as np
import torch
import facer
from PIL import Image

# Paths
base_path = '/content/drive/MyDrive/masked_images_face/'
data_types = ['train', 'test']
output_folder = '/content/drive/MyDrive/skin_only_images'

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load facer models
face_detector = facer.face_detector('retinaface/mobilenet', device=device)
face_parser = facer.face_parser('farl/lapa/448', device=device)

def process_image(image_path, device):
    """Process a single image to extract the face skin region."""
    # Load and check image
    sample = cv2.imread(image_path)
    if sample is None:
        print(f"Failed to load image: {image_path}")
        return None

    img = cv2.cvtColor(sample, cv2.COLOR_BGR2RGB)

    # Read and preprocess the image for facer
    image = facer.hwc2bchw(facer.read_hwc(image_path)).to(device)
    with torch.inference_mode():
        faces = face_detector(image)
        if faces['rects'].nelement() == 0:
            print(f"No faces detected in {os.path.basename(image_path)}, skipping...")
            return None

        faces = face_parser(image, faces)

    # Parse the face skin
    seg_logits = faces['seg']['logits']
    seg_probs = seg_logits.softmax(dim=1).cpu()
    tensor = seg_probs.permute(0, 2, 3, 1).squeeze().numpy()
    face_skin = tensor[:, :, 1]

    # Create binary mask
    binary_mask = (face_skin >= 0.5).astype(int)
    return img, binary_mask

def save_cropped_image(img, mask, output_path, make_transparent=True):
    """
    Save the cropped image with or without transparency.
    """
    try:
        # Ensure mask and image dimensions match
        if make_transparent:
            if mask.shape[:2] != img.shape[:2]:
                mask = cv2.resize(mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)

            # Create an RGBA image
            rgba_image = np.zeros((img.shape[0], img.shape[1], 4), dtype=np.uint8)
            rgba_image[:, :, :3] = img  # Copy RGB channels
            rgba_image[:, :, 3] = (mask * 255).astype(np.uint8)  # Alpha channel

            # Save as PNG
            output_image = Image.fromarray(rgba_image, 'RGBA')
            output_image.save(output_path, format='PNG')
        else:
            # Save as a standard RGB image
            output_image = Image.fromarray(img, 'RGB')
            output_image.save(output_path, format='JPEG')

        print(f"Saved image to: {output_path}")
        return True

    except Exception as e:
        print(f"Error saving image to {output_path}: {e}")
        return False


# Process images
for data_type in data_types:
    data_path = os.path.join(base_path, data_type)
    output_data_path = os.path.join(output_folder, data_type)
    os.makedirs(output_data_path, exist_ok=True)

    for folder_name in os.listdir(data_path):
        folder_path = os.path.join(data_path, folder_name)
        output_folder_path = os.path.join(output_data_path, folder_name)
        os.makedirs(output_folder_path, exist_ok=True)

        if os.path.isdir(folder_path):
            for filename in os.listdir(folder_path):
                if filename.endswith(('.jpg', '.png')):
                    sample_path = os.path.join(folder_path, filename)
                    output_image_path = os.path.join(output_folder_path, filename.split('.')[0] + '.png')

                    # Process the image
                    result = process_image(sample_path, device)
                    if result:
                        img, mask = result
                        save_cropped_image(img, mask, output_image_path, make_transparent=True)
# Out:
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_1.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_2.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_3.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_4.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_5.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring_6.png
# Saved image to: /content/drive/MyDrive/skin_only_images/train/light spring/light_spring
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_14.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_15.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_16.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_17.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_18.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_19.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_20.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_21.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_22.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_23.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_24.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_25.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_26.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_27.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_28.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_29.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_30.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_31.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_32.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_33.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_34.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_35.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_36.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_37.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_38.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_39.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_40.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_41.png
# No faces detected in warm_autumn_42.png, skipping...
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_43.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_44.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_45.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_46.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_47.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_48.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_49.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_50.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_51.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_52.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_53.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_54.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_55.png
# No faces detected in warm_autumn_56.png, skipping...
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_57.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_58.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_59.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_60.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_61.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_62.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_63.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_64.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_65.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_66.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_67.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_68.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_69.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_70.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_71.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_72.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_73.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm autumn/warm_autumn_74.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_1.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_2.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_3.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_4.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_5.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_6.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_7.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_8.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_9.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_10.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_11.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_12.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_13.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_14.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_15.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_16.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_17.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_18.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_19.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_20.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_21.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_22.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_23.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_24.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_25.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_26.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_27.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_28.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_29.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_30.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_31.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_32.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_33.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_34.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_35.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_36.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_37.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_38.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_39.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_40.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_41.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_42.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_43.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_44.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_45.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_46.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_47.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_48.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_49.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_50.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_51.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_52.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_53.png
# No faces detected in warm_spring_54.png, skipping...
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_55.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_56.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_57.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_58.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_59.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_60.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_61.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_62.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_63.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_64.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_65.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_66.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_67.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_68.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_69.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_70.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_71.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_72.png
# Saved image to: /content/drive/MyDrive/skin_only_images/test/warm spring/warm_spring_73.png

# %% [markdown]
# Create CSV file

# %%
# importing csv
import csv

# Data
data = [
    ['hex', 'season'],
    ['#f6a390', 'clear spring'],
    ['#ff8d6d', 'clear spring'],
    ['#ed5475', 'clear spring'],
    ['#ff565b', 'clear spring'],
    ['#db2a1c', 'clear spring'],
    ['#ef61a4', 'clear spring'],
    ['#d438b4', 'clear spring'],
    ['#973cbe', 'clear spring'],
    ['#af98de', 'clear spring'],
    ['#463536', 'clear spring'],
    ['#9393d1', 'warm spring'],
    ['#973cbd', 'warm spring'],
    ['#d9281a', 'warm spring'],
    ['#b36953', 'warm spring'],
    ['#ed5138', 'warm spring'],
    ['#a5621a', 'warm spring'],
    ['#ff8000', 'warm spring'],
    ['#ffa38b', 'warm spring'],
    ['#fab57c', 'warm spring'],
    ['#ffba1c', 'warm spring'],
    ['#faac8f', 'light spring'],
    ['#fdad66', 'light spring'],
    ['#ff8d6d', 'light spring'],
    ['#fcc89a', 'light spring'],
    ['#c4b2e3', 'light spring'],
    ['#d7a8e2', 'light spring'],
    ['#f7cda7', 'light spring'],
    ['#c2a695', 'light spring'],
    ['#cfa279', 'light spring'],
    ['#9696d2', 'light spring'],
    ['#f395c7', 'clear winter'],
    ['#89189f', 'clear winter'],
    ['#a61891', 'clear winter'],
    ['#ab0062', 'clear winter'],
    ['#c5007d', 'clear winter'],
    ['#e20888', 'clear winter'],
    ['#e40047', 'clear winter'],
    ['#cb0033', 'clear winter'],
    ['#c824b2', 'clear winter'],
    ['#9c40c2', 'clear winter'],
    ['#f192c5', 'cool winter'],
    ['#83319a', 'cool winter'],
    ['#933bbc', 'cool winter'],
    ['#c622af', 'cool winter'],
    ['#db1886', 'cool winter'],
    ['#e2006b', 'cool winter'],
    ['#cf0038', 'cool winter'],
    ['#a7005e', 'cool winter'],
    ['#8a0c59', 'cool winter'],
    ['#83309a', 'deep winter'],
    ['#963cbd', 'deep winter'],
    ['#c723b0', 'deep winter'],
    ['#da1784', 'deep winter'],
    ['#e50072', 'deep winter'],
    ['#d00039', 'deep winter'],
    ['#a7005e', 'deep winter'],
    ['#991e68', 'deep winter'],
    ['#8b0b5a', 'deep winter'],
    ['#f0bbc6', 'soft summer'],
    ['#ffa3b5', 'soft summer'],
    ['#f65073', 'soft summer'],
    ['#d694ac', 'soft summer'],
    ['#a075a4', 'soft summer'],
    ['#a462b9', 'soft summer'],
    ['#a65e9a', 'soft summer'],
    ['#8a687e', 'soft summer'],
    ['#78658f', 'soft summer'],
    ['#a73b70', 'soft summer'],
    ['#f395c7', 'cool summer'],
    ['#f57eb6', 'cool summer'],
    ['#e174cc', 'cool summer'],
    ['#c660cd', 'cool summer'],
    ['#953bbc', 'cool summer'],
    ['#973392', 'cool summer'],
    ['#ae145b', 'cool summer'],
    ['#c00d3e', 'cool summer'],
    ['#e31c7a', 'cool summer'],
    ['#ee5c9f', 'cool summer'],
    ['#ecb3cb', 'light summer'],
    ['#de9ddf', 'light summer'],
    ['#f57195', 'light summer'],
    ['#f47ab3', 'light summer'],
    ['#cb67d1', 'light summer'],
    ['#a260b7', 'light summer'],
    ['#af98dd', 'light summer'],
    ['#9999d4', 'light summer'],
    ['#ccb3a5', 'light summer'],
    ['#dc874f', 'soft autumn'],
    ['#c26e5f', 'soft autumn'],
    ['#996f5b', 'soft autumn'],
    ['#935f36', 'soft autumn'],
    ['#bf502f', 'soft autumn'],
    ['#7a4b38', 'soft autumn'],
    ['#554942', 'soft autumn'],
    ['#b68251', 'soft autumn'],
    ['#a47800', 'warm autumn'],
    ['#a7641b', 'warm autumn'],
    ['#946037', 'warm autumn'],
    ['#9b4514', 'warm autumn'],
    ['#7c4d3a', 'warm autumn'],
    ['#a03626', 'warm autumn'],
    ['#c3602b', 'warm autumn'],
    ['#ec5037', 'warm autumn'],
    ['#ee7000', 'warm autumn'],
    ['#f68f2f', 'warm autumn'],
    ['#5e068f', 'deep autumn'],
    ['#81272b', 'deep autumn'],
    ['#643335', 'deep autumn'],
    ['#880b57', 'deep autumn'],
    ['#973cbe', 'deep autumn'],
    ['#9d3526', 'deep autumn'],
    ['#7b4c39', 'deep autumn'],
    ['#ec4d35', 'deep autumn'],
    ['#bd4c00', 'deep autumn'],
    ['#ff8300', 'deep autumn'],
    ['#c5622d', 'deep autumn']
]

# File path for the CSV file
csv_file_path = 'colors.csv'

# Open the file in write mode
with open(csv_file_path, mode='w', newline='') as file:
    # Create a csv.writer object
    writer = csv.writer(file)
    # Write data to the CSV file
    writer.writerows(data)

# Print a confirmation message
print(f"CSV file '{csv_file_path}' created successfully.")
# Out:
# CSV file 'colors.csv' created successfully.
